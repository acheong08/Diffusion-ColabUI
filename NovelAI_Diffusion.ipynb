# %% [markdown]
# # Novel AI leaked

# %% [markdown]
# Quick start:
# 1. Run `Downloading data`
# 2. Run `Getting the data to the right places`
# 3. Run `Running webui`
# 4. Follow the gradio link given (Public URL)
#
# Using Google Drive:
# - You can save the leaked model to your Google Drive `#Save the model`
# - You can load the model from your drive if you have saved it before `Using saved model`
# - If you've saved the model before, don't run `Downloading data`.

# %% [markdown]
# ## Getting resources

# %% [markdown]
# ### Downloading data

# %%
# %cd /content/
# !git clone https://github.com/acheong08/stable-diffusion-webui
# !wget https://duti.tech/novelai.zip

# %% [markdown]
# ### Use Google drive

# %%
# Save the model
from google.colab import drive
try:
   drive_path = "/content/drive"
   drive.mount(drive_path,force_remount=False)
   # !cp /content/novelai.zip /content/drive/MyDrive/AI_models/novelai.zip 
except:
   print("...error mounting drive or with drive path variables")

# %%
# Using saved model
# !git clone https://github.com/acheong08/stable-diffusion-webui
from google.colab import drive
try:
   drive_path = "/content/drive"
   drive.mount(drive_path,force_remount=False)
   # !cp /content/drive/MyDrive/AI_models/novelai.zip /content/novelai.zip 
except:
   print("...error mounting drive or with drive path variables")

# %% [markdown]
# ### Getting the data to the right places

# %%
# !unzip novelai.zip
# Out:
# Archive:  novelai.zip
#    creating: var/lib/transmission-daemon/downloads/novelaileak/
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/sha256sum.sig
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animefull-latest/
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animefull-latest/model.ckpt.part
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animefull-latest/config.yaml
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/vector_adjust/
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/vector_adjust/vector_adjust/
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/vector_adjust/vector_adjust/v2.pt.part
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/furry_protogen.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/aini.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/furry.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/pony.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/furry_3.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/furry_scalie.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/furry_transformation.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/anime.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/anime_2.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/anime_3.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/furry_2.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/furry_kemono.pt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animevae.pt
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animefull-final-pruned/
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animefull-final-pruned/model.ckpt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animefull-final-pruned/config.yaml
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animesfw-prevgood/
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animesfw-prevgood/model.ckpt.part
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/extra-sd-prune/
#    creating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/extra-sd-prune/sd-prune/
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/extra-sd-prune/sd-prune/prune.py
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/extra-sd-prune/sd-prune/anime700k-64bs-0.1ucg-penultimate-1epoch-clip-ema-continue-76000.pt.part
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/extra-sd-prune/sd-prune/anime700k-64bs-0.1ucg-penultimate-1epoch-clip-ema-continue-76000-ema-pruned.ckpt.part
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/stableckpt/clean.py
#    creating: var/lib/transmission-daemon/downloads/novelaileak/workspace/
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/workspace/sd-private.tar.zst.part
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/readme.txt
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/sha256sum
#    creating: var/lib/transmission-daemon/downloads/novelaileak/github/
#    creating: var/lib/transmission-daemon/downloads/novelaileak/github/novelai/
#  extracting: var/lib/transmission-daemon/downloads/novelaileak/github/novelai/wandb.tar.zst
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/github/novelai/hydra-node.tar.zst.part
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/github/novelai/novelai-web-default-scenarios.tar.zst.part
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/github/novelai/weblab.tar.zst
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/github/novelai/typewriterjs.tar.zst.part
#   inflating: var/lib/transmission-daemon/downloads/novelaileak/github/novelai/novelai-web.tar.zst.part

# %%
# !cp /content/var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animefull-final-pruned/model.ckpt /content/stable-diffusion-webui/models/Stable-diffusion/final-pruned.ckpt
# !cp /content/var/lib/transmission-daemon/downloads/novelaileak/stableckpt/animevae.pt /content/stable-diffusion-webui/models/Stable-diffusion/final-pruned.vae.pt
# !mkdir -p /content/stable-diffusion-webui/models/hypernetworks
# !cp /content/var/lib/transmission-daemon/downloads/novelaileak/stableckpt/modules/modules/* /content/stable-diffusion-webui/models/hypernetworks/

# %%
# Clean stuff up
# !rm -rf /content/var /content/novelai.zip

# %% [markdown]
# ## Running webui

# %%
# %cd /content/stable-diffusion-webui/
# !COMMANDLINE_ARGS="--share --gradio-debug --medvram" REQS_FILE="requirements.txt" python launch.py
# Out:
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:19,  1.01s/it]
#  10% 2/20 [00:01<00:09,  1.81it/s]
#  15% 3/20 [00:01<00:06,  2.46it/s]
#  20% 4/20 [00:01<00:05,  2.97it/s]
#  25% 5/20 [00:01<00:04,  3.34it/s]
#  30% 6/20 [00:02<00:03,  3.60it/s]
#  35% 7/20 [00:02<00:03,  3.80it/s]
#  40% 8/20 [00:02<00:03,  3.95it/s]
#  45% 9/20 [00:02<00:02,  4.05it/s]
#  50% 10/20 [00:03<00:02,  4.11it/s]
#  55% 11/20 [00:03<00:02,  4.16it/s]
#  60% 12/20 [00:03<00:01,  4.20it/s]
#  65% 13/20 [00:03<00:01,  4.22it/s]
#  70% 14/20 [00:04<00:01,  4.24it/s]
#  75% 15/20 [00:04<00:01,  4.25it/s]
#  80% 16/20 [00:04<00:00,  4.27it/s]
#  85% 17/20 [00:04<00:00,  4.26it/s]
#  90% 18/20 [00:04<00:00,  4.28it/s]
#  95% 19/20 [00:05<00:00,  4.27it/s]
# 100% 20/20 [00:05<00:00,  3.68it/s]
# Total progress: 100% 20/20 [00:05<00:00,  3.49it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:36,  1.90s/it]
#  10% 2/20 [00:03<00:26,  1.46s/it]
#  15% 3/20 [00:04<00:22,  1.33s/it]
#  20% 4/20 [00:05<00:20,  1.26s/it]
#  25% 5/20 [00:06<00:18,  1.23s/it]
#  30% 6/20 [00:07<00:16,  1.21s/it]
#  35% 7/20 [00:08<00:15,  1.20s/it]
#  40% 8/20 [00:10<00:14,  1.20s/it]
#  45% 9/20 [00:11<00:13,  1.20s/it]
#  50% 10/20 [00:12<00:11,  1.20s/it]
#  55% 11/20 [00:13<00:10,  1.20s/it]
#  60% 12/20 [00:14<00:09,  1.20s/it]
#  65% 13/20 [00:16<00:08,  1.20s/it]
#  70% 14/20 [00:17<00:07,  1.20s/it]
#  75% 15/20 [00:18<00:06,  1.21s/it]
#  80% 16/20 [00:19<00:04,  1.21s/it]
#  85% 17/20 [00:20<00:03,  1.21s/it]
#  90% 18/20 [00:22<00:02,  1.22s/it]
#  95% 19/20 [00:23<00:01,  1.22s/it]
# 100% 20/20 [00:24<00:00,  1.23s/it]
# Total progress: 100% 20/20 [00:26<00:00,  1.31s/it]
# Warning: unknown mime-type for "outputs/txt2img-images" -- using "application/octet-stream"
# Error: no "view" mailcap rules found for type "application/octet-stream"
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'outputs/txt2img-images'
# Batch 1 out of 6:   0% 0/50 [00:00<?, ?it/s]
# Batch 1 out of 6:   2% 1/50 [00:01<00:51,  1.05s/it]
# Batch 1 out of 6:   4% 2/50 [00:01<00:36,  1.33it/s]
# Batch 1 out of 6:   6% 3/50 [00:01<00:26,  1.79it/s]
# Batch 1 out of 6:   8% 4/50 [00:02<00:20,  2.28it/s]
# Batch 1 out of 6:  10% 5/50 [00:02<00:16,  2.69it/s]
# Batch 1 out of 6:  12% 6/50 [00:02<00:14,  2.96it/s]
# Batch 1 out of 6:  14% 7/50 [00:02<00:13,  3.22it/s]
# Batch 1 out of 6:  16% 8/50 [00:03<00:12,  3.40it/s]
# Batch 1 out of 6:  18% 9/50 [00:03<00:11,  3.54it/s]
# Batch 1 out of 6:  20% 10/50 [00:03<00:11,  3.63it/s]
# Batch 1 out of 6:  22% 11/50 [00:04<00:10,  3.57it/s]
# Batch 1 out of 6:  24% 12/50 [00:04<00:10,  3.68it/s]
# Batch 1 out of 6:  26% 13/50 [00:04<00:09,  3.75it/s]
# Batch 1 out of 6:  28% 14/50 [00:04<00:09,  3.76it/s]
# Batch 1 out of 6:  30% 15/50 [00:05<00:09,  3.79it/s]
# Batch 1 out of 6:  32% 16/50 [00:05<00:08,  3.83it/s]
# Batch 1 out of 6:  34% 17/50 [00:05<00:08,  3.85it/s]
# Batch 1 out of 6:  36% 18/50 [00:05<00:08,  3.85it/s]
# Batch 1 out of 6:  38% 19/50 [00:06<00:08,  3.85it/s]
# Batch 1 out of 6:  40% 20/50 [00:06<00:07,  3.86it/s]
# Batch 1 out of 6:  42% 21/50 [00:06<00:07,  3.87it/s]
# Batch 1 out of 6:  44% 22/50 [00:06<00:07,  3.86it/s]
# Batch 1 out of 6:  46% 23/50 [00:07<00:06,  3.87it/s]
# Batch 1 out of 6:  48% 24/50 [00:07<00:06,  3.88it/s]
# Batch 1 out of 6:  50% 25/50 [00:07<00:06,  3.87it/s]
# Batch 1 out of 6:  52% 26/50 [00:07<00:06,  3.87it/s]
# Batch 1 out of 6:  54% 27/50 [00:08<00:05,  3.87it/s]
# Batch 1 out of 6:  56% 28/50 [00:08<00:05,  3.88it/s]
# Batch 1 out of 6:  58% 29/50 [00:08<00:05,  3.88it/s]
# Batch 1 out of 6:  60% 30/50 [00:08<00:05,  3.87it/s]
# Batch 1 out of 6:  62% 31/50 [00:09<00:04,  3.86it/s]
# Batch 1 out of 6:  64% 32/50 [00:09<00:04,  3.87it/s]
# Batch 1 out of 6:  66% 33/50 [00:09<00:04,  3.86it/s]
# Batch 1 out of 6:  68% 34/50 [00:09<00:04,  3.87it/s]
# Batch 1 out of 6:  70% 35/50 [00:10<00:03,  3.85it/s]
# Batch 1 out of 6:  72% 36/50 [00:10<00:03,  3.85it/s]
# Batch 1 out of 6:  74% 37/50 [00:10<00:03,  3.86it/s]
# Batch 1 out of 6:  76% 38/50 [00:10<00:03,  3.86it/s]
# Batch 1 out of 6:  78% 39/50 [00:11<00:02,  3.85it/s]
# Batch 1 out of 6:  80% 40/50 [00:11<00:02,  3.85it/s]
# Batch 1 out of 6:  82% 41/50 [00:11<00:02,  3.86it/s]
# Batch 1 out of 6:  84% 42/50 [00:12<00:02,  3.86it/s]
# Batch 1 out of 6:  86% 43/50 [00:12<00:01,  3.86it/s]
# Batch 1 out of 6:  88% 44/50 [00:12<00:01,  3.86it/s]
# Batch 1 out of 6:  90% 45/50 [00:12<00:01,  3.85it/s]
# Batch 1 out of 6:  92% 46/50 [00:13<00:01,  3.86it/s]
# Batch 1 out of 6:  94% 47/50 [00:13<00:00,  3.87it/s]
# Batch 1 out of 6:  96% 48/50 [00:13<00:00,  3.85it/s]
# Batch 1 out of 6:  98% 49/50 [00:13<00:00,  3.85it/s]
# Batch 1 out of 6: 100% 50/50 [00:14<00:00,  3.54it/s]
# Downloading: "https://github.com/sczhou/CodeFormer/releases/download/v0.1.0/codeformer.pth" to /content/stable-diffusion-webui/models/Codeformer/codeformer-v0.1.0.pth
#
# 100% 359M/359M [00:06<00:00, 56.8MB/s]
# Downloading: "https://github.com/xinntao/facexlib/releases/download/v0.1.0/detection_Resnet50_Final.pth" to /content/stable-diffusion-webui/repositories/CodeFormer/weights/facelib/detection_Resnet50_Final.pth
#
# 100% 104M/104M [00:03<00:00, 28.3MB/s]
# Downloading: "https://github.com/sczhou/CodeFormer/releases/download/v0.1.0/parsing_parsenet.pth" to /content/stable-diffusion-webui/repositories/CodeFormer/weights/facelib/parsing_parsenet.pth
#
# 100% 81.4M/81.4M [00:00<00:00, 200MB/s]
# Batch 2 out of 6:   0% 0/50 [00:00<?, ?it/s]
# Batch 2 out of 6:   2% 1/50 [00:00<00:46,  1.06it/s]
# Batch 2 out of 6:   4% 2/50 [00:01<00:26,  1.84it/s]
# Batch 2 out of 6:   6% 3/50 [00:01<00:19,  2.42it/s]
# Batch 2 out of 6:   8% 4/50 [00:01<00:16,  2.82it/s]
# Batch 2 out of 6:  10% 5/50 [00:01<00:14,  3.12it/s]
# Batch 2 out of 6:  12% 6/50 [00:02<00:13,  3.34it/s]
# Batch 2 out of 6:  14% 7/50 [00:02<00:12,  3.48it/s]
# Batch 2 out of 6:  16% 8/50 [00:02<00:11,  3.58it/s]
# Batch 2 out of 6:  18% 9/50 [00:03<00:11,  3.64it/s]
# Batch 2 out of 6:  20% 10/50 [00:03<00:10,  3.70it/s]
# Batch 2 out of 6:  22% 11/50 [00:03<00:10,  3.73it/s]
# Batch 2 out of 6:  24% 12/50 [00:03<00:10,  3.75it/s]
# Batch 2 out of 6:  26% 13/50 [00:04<00:09,  3.77it/s]
# Batch 2 out of 6:  28% 14/50 [00:04<00:09,  3.79it/s]
# Batch 2 out of 6:  30% 15/50 [00:04<00:09,  3.80it/s]
# Batch 2 out of 6:  32% 16/50 [00:04<00:08,  3.80it/s]
# Batch 2 out of 6:  34% 17/50 [00:05<00:08,  3.80it/s]
# Batch 2 out of 6:  36% 18/50 [00:05<00:08,  3.81it/s]
# Batch 2 out of 6:  38% 19/50 [00:05<00:08,  3.81it/s]
# Batch 2 out of 6:  40% 20/50 [00:05<00:07,  3.80it/s]
# Batch 2 out of 6:  42% 21/50 [00:06<00:07,  3.80it/s]
# Batch 2 out of 6:  44% 22/50 [00:06<00:07,  3.80it/s]
# Batch 2 out of 6:  46% 23/50 [00:06<00:07,  3.80it/s]
# Batch 2 out of 6:  48% 24/50 [00:06<00:06,  3.79it/s]
# Batch 2 out of 6:  50% 25/50 [00:07<00:06,  3.79it/s]
# Batch 2 out of 6:  52% 26/50 [00:07<00:06,  3.80it/s]
# Batch 2 out of 6:  54% 27/50 [00:07<00:06,  3.80it/s]
# Batch 2 out of 6:  56% 28/50 [00:08<00:05,  3.80it/s]
# Batch 2 out of 6:  58% 29/50 [00:08<00:05,  3.79it/s]
# Batch 2 out of 6:  60% 30/50 [00:08<00:05,  3.80it/s]
# Batch 2 out of 6:  62% 31/50 [00:08<00:05,  3.18it/s]
# Batch 2 out of 6:  64% 32/50 [00:09<00:05,  3.35it/s]
# Batch 2 out of 6:  66% 33/50 [00:09<00:04,  3.48it/s]
# Batch 2 out of 6:  68% 34/50 [00:09<00:04,  3.54it/s]
# Batch 2 out of 6:  70% 35/50 [00:10<00:04,  3.61it/s]
# Batch 2 out of 6:  72% 36/50 [00:10<00:03,  3.67it/s]
# Batch 2 out of 6:  74% 37/50 [00:10<00:03,  3.71it/s]
# Batch 2 out of 6:  76% 38/50 [00:10<00:03,  3.71it/s]
# Batch 2 out of 6:  78% 39/50 [00:11<00:02,  3.73it/s]
# Batch 2 out of 6:  80% 40/50 [00:11<00:02,  3.75it/s]
# Batch 2 out of 6:  82% 41/50 [00:11<00:02,  3.75it/s]
# Batch 2 out of 6:  84% 42/50 [00:11<00:02,  3.75it/s]
# Batch 2 out of 6:  86% 43/50 [00:12<00:01,  3.77it/s]
# Batch 2 out of 6:  88% 44/50 [00:12<00:01,  3.77it/s]
# Batch 2 out of 6:  90% 45/50 [00:12<00:01,  3.78it/s]
# Batch 2 out of 6:  92% 46/50 [00:12<00:01,  3.77it/s]
# Batch 2 out of 6:  94% 47/50 [00:13<00:00,  3.78it/s]
# Batch 2 out of 6:  96% 48/50 [00:13<00:00,  3.78it/s]
# Batch 2 out of 6:  98% 49/50 [00:13<00:00,  3.77it/s]
# Batch 2 out of 6: 100% 50/50 [00:14<00:00,  3.57it/s]
# Batch 3 out of 6:   0% 0/50 [00:00<?, ?it/s]
# Batch 3 out of 6:   2% 1/50 [00:00<00:41,  1.17it/s]
# Batch 3 out of 6:   4% 2/50 [00:01<00:24,  1.96it/s]
# Batch 3 out of 6:   6% 3/50 [00:01<00:18,  2.51it/s]
# Batch 3 out of 6:   8% 4/50 [00:01<00:16,  2.86it/s]
# Batch 3 out of 6:  10% 5/50 [00:01<00:14,  3.14it/s]
# Batch 3 out of 6:  12% 6/50 [00:02<00:13,  3.32it/s]
# Batch 3 out of 6:  14% 7/50 [00:02<00:12,  3.45it/s]
# Batch 3 out of 6:  16% 8/50 [00:02<00:11,  3.52it/s]
# Batch 3 out of 6:  18% 9/50 [00:02<00:11,  3.60it/s]
# Batch 3 out of 6:  20% 10/50 [00:03<00:10,  3.64it/s]
# Batch 3 out of 6:  22% 11/50 [00:03<00:10,  3.66it/s]
# Batch 3 out of 6:  24% 12/50 [00:03<00:10,  3.67it/s]
# Batch 3 out of 6:  26% 13/50 [00:04<00:10,  3.70it/s]
# Batch 3 out of 6:  28% 14/50 [00:04<00:09,  3.68it/s]
# Batch 3 out of 6:  30% 15/50 [00:04<00:09,  3.69it/s]
# Batch 3 out of 6:  32% 16/50 [00:04<00:09,  3.71it/s]
# Batch 3 out of 6:  34% 17/50 [00:05<00:08,  3.71it/s]
# Batch 3 out of 6:  36% 18/50 [00:05<00:08,  3.71it/s]
# Batch 3 out of 6:  38% 19/50 [00:05<00:08,  3.71it/s]
# Batch 3 out of 6:  40% 20/50 [00:05<00:08,  3.71it/s]
# Batch 3 out of 6:  42% 21/50 [00:06<00:07,  3.72it/s]
# Batch 3 out of 6:  44% 22/50 [00:06<00:07,  3.73it/s]
# Batch 3 out of 6:  46% 23/50 [00:06<00:07,  3.72it/s]
# Batch 3 out of 6:  48% 24/50 [00:07<00:06,  3.72it/s]
# Batch 3 out of 6:  50% 25/50 [00:07<00:06,  3.72it/s]
# Batch 3 out of 6:  52% 26/50 [00:07<00:06,  3.72it/s]
# Batch 3 out of 6:  54% 27/50 [00:07<00:06,  3.72it/s]
# Batch 3 out of 6:  56% 28/50 [00:08<00:05,  3.73it/s]
# Batch 3 out of 6:  58% 29/50 [00:08<00:05,  3.73it/s]
# Batch 3 out of 6:  60% 30/50 [00:08<00:05,  3.72it/s]
# Batch 3 out of 6:  62% 31/50 [00:08<00:05,  3.72it/s]
# Batch 3 out of 6:  64% 32/50 [00:09<00:04,  3.73it/s]
# Batch 3 out of 6:  66% 33/50 [00:09<00:04,  3.71it/s]
# Batch 3 out of 6:  68% 34/50 [00:09<00:04,  3.73it/s]
# Batch 3 out of 6:  70% 35/50 [00:09<00:04,  3.73it/s]
# Batch 3 out of 6:  72% 36/50 [00:10<00:03,  3.73it/s]
# Batch 3 out of 6:  74% 37/50 [00:10<00:03,  3.72it/s]
# Batch 3 out of 6:  76% 38/50 [00:10<00:03,  3.72it/s]
# Batch 3 out of 6:  78% 39/50 [00:11<00:02,  3.73it/s]
# Batch 6 out of 6:   6% 3/50 [00:01<00:18,  2.56it/s]
# Batch 6 out of 6:   8% 4/50 [00:01<00:15,  2.92it/s]
# Batch 6 out of 6:  10% 5/50 [00:01<00:14,  3.21it/s]
# Batch 6 out of 6:  12% 6/50 [00:02<00:12,  3.41it/s]
# Batch 6 out of 6:  14% 7/50 [00:02<00:12,  3.55it/s]
# Batch 6 out of 6:  16% 8/50 [00:02<00:11,  3.62it/s]
# Batch 6 out of 6:  18% 9/50 [00:02<00:11,  3.70it/s]
# Batch 6 out of 6:  20% 10/50 [00:03<00:10,  3.75it/s]
# Batch 6 out of 6:  22% 11/50 [00:03<00:10,  3.78it/s]
# Batch 6 out of 6:  24% 12/50 [00:03<00:09,  3.80it/s]
# Batch 6 out of 6:  26% 13/50 [00:03<00:09,  3.82it/s]
# Batch 6 out of 6:  28% 14/50 [00:04<00:09,  3.84it/s]
# Batch 6 out of 6:  30% 15/50 [00:04<00:09,  3.84it/s]
# Batch 6 out of 6:  32% 16/50 [00:04<00:08,  3.84it/s]
# Batch 6 out of 6:  34% 17/50 [00:05<00:08,  3.85it/s]
# Batch 6 out of 6:  36% 18/50 [00:05<00:08,  3.86it/s]
# Batch 6 out of 6:  38% 19/50 [00:05<00:08,  3.86it/s]
# Batch 6 out of 6:  40% 20/50 [00:05<00:07,  3.85it/s]
# Batch 6 out of 6:  42% 21/50 [00:06<00:07,  3.85it/s]
# Batch 6 out of 6:  44% 22/50 [00:06<00:07,  3.86it/s]
# Batch 6 out of 6:  46% 23/50 [00:06<00:07,  3.85it/s]
# Batch 6 out of 6:  48% 24/50 [00:06<00:06,  3.85it/s]
# Batch 6 out of 6:  50% 25/50 [00:07<00:06,  3.86it/s]
# Batch 6 out of 6:  52% 26/50 [00:07<00:06,  3.86it/s]
# Batch 6 out of 6:  54% 27/50 [00:07<00:05,  3.86it/s]
# Batch 6 out of 6:  56% 28/50 [00:07<00:05,  3.85it/s]
# Batch 6 out of 6:  58% 29/50 [00:08<00:05,  3.86it/s]
# Batch 6 out of 6:  60% 30/50 [00:08<00:05,  3.86it/s]
# Batch 6 out of 6:  62% 31/50 [00:08<00:04,  3.85it/s]
# Batch 6 out of 6:  64% 32/50 [00:08<00:04,  3.86it/s]
# Batch 6 out of 6:  66% 33/50 [00:09<00:04,  3.86it/s]
# Batch 6 out of 6:  68% 34/50 [00:09<00:04,  3.86it/s]
# Batch 6 out of 6:  70% 35/50 [00:09<00:03,  3.86it/s]
# Batch 6 out of 6:  72% 36/50 [00:09<00:03,  3.87it/s]
# Batch 6 out of 6:  74% 37/50 [00:10<00:03,  3.87it/s]
# Batch 6 out of 6:  76% 38/50 [00:10<00:03,  3.87it/s]
# Batch 6 out of 6:  78% 39/50 [00:10<00:02,  3.86it/s]
# Batch 6 out of 6:  80% 40/50 [00:10<00:02,  3.86it/s]
# Batch 6 out of 6:  82% 41/50 [00:11<00:02,  3.85it/s]
# Batch 6 out of 6:  84% 42/50 [00:11<00:02,  3.86it/s]
# Batch 6 out of 6:  86% 43/50 [00:11<00:01,  3.85it/s]
# Batch 6 out of 6:  88% 44/50 [00:12<00:01,  3.85it/s]
# Batch 6 out of 6:  90% 45/50 [00:12<00:01,  3.85it/s]
# Batch 6 out of 6:  92% 46/50 [00:12<00:01,  3.85it/s]
# Batch 6 out of 6:  94% 47/50 [00:12<00:00,  3.85it/s]
# Batch 6 out of 6:  96% 48/50 [00:13<00:00,  3.85it/s]
# Batch 6 out of 6:  98% 49/50 [00:13<00:00,  3.85it/s]
# Batch 6 out of 6: 100% 50/50 [00:13<00:00,  3.69it/s]
# Total progress: 100% 300/300 [01:46<00:00,  2.83it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:37,  1.95s/it]
#  10% 2/20 [00:03<00:27,  1.55s/it]
#  15% 3/20 [00:04<00:24,  1.43s/it]
#  20% 4/20 [00:05<00:22,  1.38s/it]
#  25% 5/20 [00:07<00:20,  1.35s/it]
#  30% 6/20 [00:08<00:18,  1.33s/it]
#  35% 7/20 [00:09<00:17,  1.32s/it]
#  40% 8/20 [00:11<00:15,  1.32s/it]
#  45% 9/20 [00:12<00:14,  1.32s/it]
#  50% 10/20 [00:13<00:13,  1.32s/it]
#  55% 11/20 [00:14<00:11,  1.32s/it]
#  60% 12/20 [00:16<00:10,  1.32s/it]
#  65% 13/20 [00:17<00:09,  1.32s/it]
#  70% 14/20 [00:18<00:07,  1.32s/it]
#  75% 15/20 [00:20<00:06,  1.32s/it]
#  80% 16/20 [00:21<00:05,  1.32s/it]
#  85% 17/20 [00:22<00:03,  1.32s/it]
#  90% 18/20 [00:24<00:02,  1.32s/it]
#  95% 19/20 [00:25<00:01,  1.31s/it]
# 100% 20/20 [00:26<00:00,  1.34s/it]
# Total progress: 20it [00:28,  1.41s/it]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:18,  1.04it/s]
#  10% 2/20 [00:01<00:09,  1.86it/s]
#  15% 3/20 [00:01<00:06,  2.48it/s]
#  20% 4/20 [00:01<00:05,  2.93it/s]
#  25% 5/20 [00:01<00:04,  3.24it/s]
#  30% 6/20 [00:02<00:04,  3.47it/s]
#  35% 7/20 [00:02<00:03,  3.64it/s]
#  40% 8/20 [00:02<00:03,  3.76it/s]
#  45% 9/20 [00:02<00:02,  3.83it/s]
#  50% 10/20 [00:03<00:02,  3.88it/s]
#  55% 11/20 [00:03<00:02,  3.93it/s]
#  60% 12/20 [00:03<00:02,  3.96it/s]
#  65% 13/20 [00:03<00:01,  3.97it/s]
#  70% 14/20 [00:04<00:01,  3.98it/s]
#  75% 15/20 [00:04<00:01,  4.00it/s]
#  80% 16/20 [00:04<00:00,  4.02it/s]
#  85% 17/20 [00:04<00:00,  4.01it/s]
#  90% 18/20 [00:05<00:00,  4.01it/s]
#  95% 19/20 [00:05<00:00,  4.02it/s]
# 100% 20/20 [00:05<00:00,  3.53it/s]
# Total progress: 100% 20/20 [00:05<00:00,  3.45it/s]
